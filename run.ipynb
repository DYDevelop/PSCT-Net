# %%
python3 train.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=0 --dataroot=../Datasets/LIDC-HDF5-256/LIDC-HDF5-256 \
--dataset=train --tag=LIDC_IDRI_mamba --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/LIDC-HDF5-256/train.txt \
--valid_datasetfile=../Datasets/LIDC-HDF5-256/test.txt \
--valid_dataset=test

# %%
python3 test.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=0  --dataroot=../Datasets/LIDC-HDF5-256/LIDC-HDF5-256 \
--dataset=test --tag=d2_multiview2500 --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/LIDC-HDF5-256/test.txt \
--resultdir=./multiview --check_point=100 \
--load_path=./save_models/multiView_CTGAN/LIDC256/LIDC_IDRI_mamba/checkpoint

# %% [markdown]
# # Facial Only

# %%
python3 train.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=0 --dataroot=../Datasets/Facial_only/Dataset \
--dataset=train --tag=BPJCT_Skull_facial --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/Facial_only/train.txt \
--valid_datasetfile=../Datasets/Facial_only/test.txt \
--valid_dataset=test

# %%
python3 test.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=0  --dataroot=../Datasets/Facial_only/Dataset \
--dataset=test --tag=d2_multiview2500 --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/Facial_only/test.txt \
--resultdir=./multiview --check_point=100 \
--load_path=./save_models/multiView_CTGAN/LIDC256/BPJCT_Skull_facial/checkpoint

# %%
python3 visual.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml --gpu=0 \
--dataroot=../Datasets/Facial_only/Dataset \
--dataset=test --tag=d2_multiview2500 --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/Facial_only/test.txt \
--resultdir=./multiview --check_point=100 \
--load_path=./save_models/multiView_CTGAN/LIDC256/BPJCT_Skull_facial/checkpoint \
--how_many=10

# %%
python3 generation.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml --gpu=0 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--resultdir=./multiview --check_point=100 \
--load_path=./save_models/multiView_CTGAN/LIDC256/BPJCT_Skull_facial/checkpoint

# %% [markdown]
# # Brain Only

# %%
python3 train.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=1 --dataroot=../Datasets/Brain_only/Dataset \
--dataset=train --tag=BPJCT_Skull_brain --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/Brain_only/train.txt \
--valid_datasetfile=../Datasets/Brain_only/test.txt \
--valid_dataset=test

# %%
python3 train_best.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=0,1,2,3 --dataroot=../Datasets/Brain_only/Dataset \
--dataset=train --tag=BPJCT_Skull_brain_best --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/Brain_only/train.txt \
--valid_datasetfile=../Datasets/Brain_only/test.txt \
--valid_dataset=test

# %%
python3 test.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=0 --dataroot=../Datasets/Brain_only/Dataset \
--dataset=test --tag=d2_multiview2500 --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/Brain_only/test.txt \
--resultdir=./multiview --check_point=40 \
--load_path=./save_models/multiView_CTGAN/LIDC256/BPJCT_Skull_brain_best/checkpoint

# %%
python3 visual.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml --gpu=0 \
--dataroot=../Datasets/Brain_only/Dataset \
--dataset=test --tag=d2_multiview2500 --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/Brain_only/test.txt \
--resultdir=./multiview --check_point=100 \
--load_path=./save_models/multiView_CTGAN/LIDC256/BPJCT_Skull_brain/checkpoint \
--how_many=10

# %%
python3 generation.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml --gpu=0 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--resultdir=./multiview --check_point=100 \
--load_path=./save_models/multiView_CTGAN/LIDC256/BPJCT_Skull_brain/checkpoint

# %%
python3 generation_folder.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml --gpu=0 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--resultdir=./multiview --check_point=100 \
--load_path=./save_models/multiView_CTGAN/LIDC256/BPJCT_Skull_brain/checkpoint

# %% [markdown]
# # CTPelvic1K

# %% [markdown]
# - BPJCT_CTPelvic1K_ep100v2 ep 60 -> 33.39, 29.44

# %%
python3 train.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=0,1 --dataroot=../Datasets/CTPelvic1K/Dataset \
--dataset=train --tag=BPJCT_CTPelvic1K --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/CTPelvic1K/train.txt \
--valid_datasetfile=../Datasets/CTPelvic1K/test.txt \
--valid_dataset=test

# %%
python3 train_best.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=0,1 --dataroot=../Datasets/CTPelvic1K/Dataset \
--dataset=train --tag=BPJCT_CTPelvic1K_ep100v2 --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/CTPelvic1K/train.txt \
--valid_datasetfile=../Datasets/CTPelvic1K/test.txt \
--valid_dataset=test

# %%
python3 train_best.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=2,3 --dataroot=../Datasets/CTPelvic1K/Dataset \
--dataset=train --tag=BPJCT_CTPelvic1K_ep100v3 --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/CTPelvic1K/train.txt \
--valid_datasetfile=../Datasets/CTPelvic1K/test.txt \
--valid_dataset=test

# %%
python3 test.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=0  --dataroot=../Datasets/CTPelvic1K/Dataset \
--dataset=test --tag=d2_multiview2500 --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/CTPelvic1K/test.txt \
--resultdir=./multiview --check_point=60 \
--load_path=./save_models/multiView_CTGAN/LIDC256/BPJCT_CTPelvic1K/checkpoint

# %% [markdown]
# # CTSpine1K

# %%
python3 train.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=0,1,2,3 --dataroot=../Datasets/CTSpine1K/Dataset \
--dataset=train --tag=BPJCT_CTSpine1K_ep250 --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/CTSpine1K/train.txt \
--valid_datasetfile=../Datasets/CTSpine1K/test.txt \
--valid_dataset=test

# %%
python3 train.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=2,3 --dataroot=../Datasets/CTSpine1K/Dataset \
--dataset=train --tag=BPJCT_CTSpine1K_ep150 --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/CTSpine1K/train.txt \
--valid_datasetfile=../Datasets/CTSpine1K/test.txt \
--valid_dataset=test

# %% [markdown]
# - BPJCT_CTSpine1K_ep200v2 ep 100 --> 21.73, 21.09 (1225, no_stratify)
# - BPJCT_CTSpine1K_ep200v4 ep 63 --> 22.40, 21.82 (1225, no_stratify, (50, 150))

# %%
python3 test.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=0  --dataroot=../Datasets/CTSpine1K/Dataset \
--dataset=test --tag=d2_multiview2500 --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/CTSpine1K/test.txt \
--resultdir=./multiview --check_point=63 \
--load_path=./save_models/multiView_CTGAN/LIDC256/BPJCT_CTSpine1K_ep200v4/checkpoint

# %%
python3 train.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=0,1 --dataroot=../Datasets/CTSpine1K/Dataset \
--dataset=train --tag=BPJCT_CTSpine1K_ep200v2 --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/CTSpine1K/train.txt \
--valid_datasetfile=../Datasets/CTSpine1K/test.txt \
--valid_dataset=test

# %%
python3 train_best.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=0,1 --dataroot=../Datasets/CTSpine1K/Dataset \
--dataset=train --tag=BPJCT_CTSpine1K_ep200v3 --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/CTSpine1K/train.txt \
--valid_datasetfile=../Datasets/CTSpine1K/test.txt \
--valid_dataset=test

# %%
python3 train_best.py --ymlpath=./experiment/multiview2500/d2_multiview2500_BP.yml \
--gpu=2,3 --dataroot=../Datasets/CTSpine1K/Dataset \
--dataset=train --tag=BPJCT_CTSpine1K_ep200v4 --data=LIDC256 \
--dataset_class=align_ct_xray_views_std --model_class=MultiViewCTGAN \
--datasetfile=../Datasets/CTSpine1K/train.txt \
--valid_datasetfile=../Datasets/CTSpine1K/test.txt \
--valid_dataset=test
